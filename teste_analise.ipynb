# %% [markdown]
# #test
# *analise*

# %%
from configs.funcoes import ler_csv
import pandas as pd
import plotly.express as px

df = ler_csv('Customer Loyalty History.csv')
display(df)
# Out:
#        Loyalty Number Country          Province        City Postal Code  \
# 0              480934  Canada           Ontario     Toronto     M2Z 4K1
# 1              549612  Canada           Alberta    Edmonton     T3G 6Y6
# 2              429460  Canada  British Columbia   Vancouver     V6E 3D9
# 3              608370  Canada           Ontario     Toronto     P1W 1K4
# 4              530508  Canada            Quebec        Hull     J8Y 3Z5
# ...               ...     ...               ...         ...         ...
# 16732          823768  Canada  British Columbia   Vancouver     V6E 3Z3
# 16733          680886  Canada      Saskatchewan      Regina     S1J 3C5
# 16734          776187  Canada  British Columbia   Vancouver     V5R 1W3
# 16735          906428  Canada             Yukon  Whitehorse     Y2K 6R0
# 16736          652627  Canada          Manitoba    Winnipeg     R2C 0M5
#
#        Gender Education    Salary Marital Status Loyalty Card       CLV  \
# ...

# %%
df = df.drop(columns='Loyalty Number')
df = df.dropna()
display(df)
display(df.info())
# Out:
#       Country          Province            City Postal Code  Gender Education  \
# 31     Canada           Ontario          Ottawa     K1F 2R2  Female  Bachelor
# 39     Canada  British Columbia       Vancouver     V5R 1W3  Female  Bachelor
# 45     Canada           Ontario     Thunder Bay     K8T 5M5  Female  Bachelor
# 51     Canada           Ontario         Sudbury     M5V 1G5  Female  Bachelor
# 65     Canada           Alberta        Edmonton     T9G 1W3  Female  Bachelor
# ...       ...               ...             ...         ...     ...       ...
# 16676  Canada             Yukon      Whitehorse     Y2K 6R0  Female  Bachelor
# 16678  Canada          Manitoba        Winnipeg     R6Y 4T5  Female  Bachelor
# 16713  Canada  British Columbia  West Vancouver     V6V 8Z3    Male  Bachelor
# 16730  Canada           Ontario         Toronto     M1R 4K3  Female  Bachelor
# 16736  Canada          Manitoba        Winnipeg     R2C 0M5  Female  Bachelor
#
# ...

# %%
for coluna in df.columns:
    grafico = px.histogram(df, x=coluna, y='Salary', color='Gender')
    grafico.show()
